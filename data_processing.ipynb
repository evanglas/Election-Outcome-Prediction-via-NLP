# %%
import pandas as pd
import numpy as np
from nltk.text import Text
from nltk.tokenize import word_tokenize
import nltk
import spacy
import re
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from unidecode import unidecode

nlp = spacy.load("en_core_web_lg")

nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")

stemmer = PorterStemmer()

from tqdm import tqdm

covid_words = {"covid", "coronavirus", "pandemic"}

import pickle
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\19083\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\19083\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\19083\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df_a = pd.read_parquet("parquets/articles.parquet")[
    ["sourcedomain_id", "date", "title", "content"]
]

# %%
def covid_docs(df):
    outlets = pd.read_csv("CSVs/outlets.csv")

    demographics = pd.read_csv("CSVs/demographics.csv")

    politics = pd.read_csv("CSVs/politics.csv")

    risks = pd.read_csv("CSVs/risks.csv")

    p1 = politics[~politics.logodds_Trump20.str.contains("None")][
        ["fips", "logodds_Trump20"]
    ]

    p1 = p1.astype({"fips": "int", "logodds_Trump20": "float"})

    p1["trump_20_pct"] = p1.logodds_Trump20.rank(pct=True)

    p1["trump_odds"] = np.exp(p1.logodds_Trump20) / (1 + np.exp(p1.logodds_Trump20))

    op = outlets.merge(p1, on="fips", how="inner")[
        [
            "sourcedomain_id",
            "fips",
            "state",
            "city",
            "logodds_Trump20",
            "trump_20_pct",
            "trump_odds",
        ]
    ]

    opd = op.merge(demographics, on="fips", how="inner")

    states = outlets[["sourcedomain_id", "fips", "state"]]

    df.reset_index(inplace=True)

    covid_df = df.drop("index", axis=1)

    covid_df["content_c"] = [
        re.sub(r"[^a-zA-Z\s]", "", doc.replace("\n", " ")) for doc in df.content
    ]

    covid_df = covid_df[
        covid_df.content_c.str.contains("covid|coronavirus|pandemic", case=False)
    ]

    covid_df["content_c"] = [re.sub(r"\s+", " ", doc) for doc in covid_df.content_c]

    covid_df = covid_df.merge(op, on="sourcedomain_id", how="inner")

    polar_covid_df = covid_df.loc[(covid_df.trump_20_pct - 0.5).abs() >= 0.25]

    polar_covid_df["trump"] = polar_covid_df.trump_20_pct > 0.5
    return polar_covid_df


def get_concordance_df(polar_covid_df):
    c_dat = []

    for index, row in tqdm(polar_covid_df.iterrows()):
        doc = Text(word_tokenize(row.content_c))
        label = row.trump
        tpc = row.trump_20_pct

        for cw in covid_words:
            res = doc.concordance_list(cw, width=300)
            for r in res:
                c_dat.append([r.line, label, tpc])
    cl = pd.DataFrame(c_dat, columns=["line", "trump", "trump_20_pct"])
    cl["line"] = [" ".join(line.split()[1:-1]) for line in cl.line]
    return cl


def clean_document(doc):
    doc = nlp(doc)
    doc_cleaned = " ".join(
        [
            token.text
            for token in doc
            if (
                token.ent_type_ not in {"GPE", "PERSON", "ORG"}
                or (token.text.lower() in covid_words)
            )
        ]
    )
    doc_cleaned = doc_cleaned.lower()
    # tokens = word_tokenize(doc)
    # stemmed = [stemmer.stem(token) for token in tokens]
    # lemmatized = [nlp(token)[0].lemma_ for token in stemmed]
    return doc, doc_cleaned


def get_clean_docs(cl):
    clean_docs = []
    nlp_docs = []
    for doc in tqdm(cl.line):
        nlp_doc, clean_doc = clean_document(doc)
        clean_docs.append(clean_doc)
        nlp_docs.append(nlp_doc)
    cl["clean_lines"] = clean_docs
    return cl, nlp_docs

# %%
# df_a = covid_docs(df_a)
# df_a = get_concordance_df(df_a)
df_a_100k = df_a.groupby("trump").apply(lambda x: x.sample(50000))

# %%
df_a_100k_c, nlp_100k_c = get_clean_docs(df_a_100k)
# Out:
# 100%|██████████| 100000/100000 [2:48:16<00:00,  9.90it/s]

# %%
df_a_100k.to_parquet("covid_mentions_equal.parquet")

# %%
len(df_a.line[90000])
# Out:
# 291

# %%
df_a_100k_c.to_parquet("covid_mentions_equal_clean.parquet")

# %%
import pickle

# %%
with open("nlp_docs_equal.pkl", "wb") as f:
    pickle.dump(nlp_100k_c, f)

# %%
df_a
# Out:
#                                   sourcedomain_id        date  \
# 0         andalusiastarnews-andalusiastarnews.com  2020-04-04
# 1         andalusiastarnews-andalusiastarnews.com  2020-04-04
# 2         andalusiastarnews-andalusiastarnews.com  2020-04-03
# 3         andalusiastarnews-andalusiastarnews.com  2020-04-06
# 4         andalusiastarnews-andalusiastarnews.com  2020-04-06
# ...                                           ...         ...
# 536258  everettindependent-everettindependent.com  2021-04-21
# 536259  everettindependent-everettindependent.com  2021-04-21
# 536260  everettindependent-everettindependent.com  2021-04-21
# 536261  everettindependent-everettindependent.com  2021-04-28
# 536262  everettindependent-everettindependent.com  2021-04-28
#
#                                                     title  \
# 0                     Remember When: Shehan’s Polio story
# 1                      Governor issues stay at home order
# 2       Local banks await final rules, guidance for pa...
# 3                             Changes  in place  for SNAP
# 4       Local boy teaches how to make masks without se...
# ...                                                   ...
# 536258  Bishop Brown, Patti Cheever Focus Radio Show o...
# 536259  Without Visits, Traditional Process, Seniors T...
# 536260   DiBiaso Leads CM to Mass. Football’s Top Ranking
# 536261  COVID-19 Cases Decline Significantly from Last...
# 536262  Percentages of Students Returning Declines as ...
#
#                                                   content  \
# 0       Dan Shehan’s “My Polio Story” is continued in ...
# 1       Governor Kay Ivey announced that a stay at hom...
# 2       As the novel coronavirus (COVID-19) disease co...
# 3       The COVID-19 pandemic has left thousands of Al...
# 4       Andalusia Elementary School second grader Blan...
# ...                                                   ...
# 536258  It’s Monday night on Broadway, and upstairs in...
# 536259  Choosing a college is typically a rite of pass...
# 536260  Everett resident John DiBiaso finds himself in...
# 536261  The numbers of COVID-19 cases in Everett has d...
# 536262  More students returned to the Everett Public S...
#
#                                                 content_c   fips  \
# 0       Dan Shehans My Polio Story is continued in thi...   1039
# 1       Governor Kay Ivey announced that a stay at hom...   1039
# 2       As the novel coronavirus COVID disease continu...   1039
# 3       The COVID pandemic has left thousands of Alaba...   1039
# 4       Andalusia Elementary School second grader Blan...   1039
# ...                                                   ...    ...
# 536258  Its Monday night on Broadway and upstairs in t...  25017
# 536259  Choosing a college is typically a rite of pass...  25017
# 536260  Everett resident John DiBiaso finds himself in...  25017
# 536261  The numbers of COVID cases in Everett has decr...  25017
# 536262  More students returned to the Everett Public S...  25017
#
#                 state       city  logodds_Trump20  trump_20_pct  trump_odds  \
# 0             Alabama  Andalusia         1.680054      0.984127    0.842912
# 1             Alabama  Andalusia         1.680054      0.984127    0.842912
# 2             Alabama  Andalusia         1.680054      0.984127    0.842912
# 3             Alabama  Andalusia         1.680054      0.984127    0.842912
# 4             Alabama  Andalusia         1.680054      0.984127    0.842912
# ...               ...        ...              ...           ...         ...
# 536258  Massachusetts    Everett        -0.987032      0.083333    0.271499
# 536259  Massachusetts    Everett        -0.987032      0.083333    0.271499
# 536260  Massachusetts    Everett        -0.987032      0.083333    0.271499
# 536261  Massachusetts    Everett        -0.987032      0.083333    0.271499
# 536262  Massachusetts    Everett        -0.987032      0.083333    0.271499
#
#         trump
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 536258  False
# 536259  False
# 536260  False
# 536261  False
# 536262  False
#
# [302612 rows x 12 columns]

# %%
cl.to_parquet("covid_mentions.parquet")

# %%
import pickle

with open("nlp_docs.pkl", "wb") as f:
    pickle.dump(nlp_docs, f)
